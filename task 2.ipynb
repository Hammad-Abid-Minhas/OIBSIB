# %% [markdown]
# <a href="https://colab.research.google.com/github/Hammad-Abid-Minhas/OIBSIB/blob/main/task%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_set1 = pd.read_csv('Unemployment_Rate_upto_11_2020.csv')

# %%
data_set2=pd.read_csv('Unemployment in India.csv')

# %%
data_set1
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
data_set2
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
data_set1.sample(6)
# Out:
#                Region         Date  Frequency  \
# 152         Meghalaya   30-04-2020          M
# 86   Himachal Pradesh   31-07-2020          M
# 257       West Bengal   31-01-2020          M
# 197         Rajasthan   30-09-2020          M
# 104         Jharkhand   30-06-2020          M
# 20              Bihar   31-01-2020          M
#
#       Estimated Unemployment Rate (%)   Estimated Employed  \
# 152                             10.03               965057
# 86                              24.31              2229456
# 257                              6.94             35820789
# 197                             15.35             20149594
# 104                             20.95              8622722
# 20                              10.61             26397671
#
#       Estimated Labour Participation Rate (%)   Region.1  longitude  latitude
# 152                                     45.99  Northeast    25.4670   91.3662
# ...

# %%
data_set2.sample(6)
# Out:
#                Region         Date  Frequency  \
# 727       Uttarakhand   30-06-2019    Monthly
# 268         Rajasthan   30-04-2020    Monthly
# 749       West Bengal   29-02-2020    Monthly
# 117  Himachal Pradesh   29-02-2020    Monthly
# 291         Telangana   30-06-2019    Monthly
# 80            Gujarat   31-05-2019    Monthly
#
#       Estimated Unemployment Rate (%)   Estimated Employed  \
# 727                              4.69             906889.0
# 268                             12.25           13051219.0
# 749                              7.55           10871168.0
# 117                             15.42            1952464.0
# 291                              5.92           10728822.0
# 80                               2.88           13954728.0
#
#       Estimated Labour Participation Rate (%)   Area
# 727                                     33.54  Urban
# 268                                     35.21  Rural
# 749                                     44.09  Urban
# ...

# %%
data_set1.head(4)
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
#
#    longitude  latitude
# 0    15.9129     79.74
# 1    15.9129     79.74
# 2    15.9129     79.74
# 3    15.9129     79.74

# %%
data_set1.tail(4)
# Out:
#           Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 263  West Bengal   31-07-2020          M                              6.83
# 264  West Bengal   31-08-2020          M                             14.87
# 265  West Bengal   30-09-2020          M                              9.35
# 266  West Bengal   31-10-2020          M                              9.98
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 263             35372506                                     46.17     East
# 264             33298644                                     47.48     East
# 265             35707239                                     47.73     East
# 266             33962549                                     45.63     East
#
#      longitude  latitude
# 263    22.9868    87.855
# 264    22.9868    87.855
# 265    22.9868    87.855
# 266    22.9868    87.855

# %%
data_set2.head(4)
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural

# %%
data_set2.tail(4)
# Out:
#     Region  Date  Frequency   Estimated Unemployment Rate (%)  \
# 764    NaN   NaN        NaN                               NaN
# 765    NaN   NaN        NaN                               NaN
# 766    NaN   NaN        NaN                               NaN
# 767    NaN   NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Area
# 764                  NaN                                       NaN  NaN
# 765                  NaN                                       NaN  NaN
# 766                  NaN                                       NaN  NaN
# 767                  NaN                                       NaN  NaN

# %%
data_set1.shape
# Out:
# (267, 9)

# %%
data_set2.shape
# Out:
# (768, 7)

# %%
data_set1.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %%
data_set2.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
data_set1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
data_set2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
print("Total NULL values =\n\n",data_set1.isnull().sum())
# Out:
# Total NULL values =
#
#  Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
print("Total NULL values =\n\n",data_set2.isnull().sum())
# Out:
# Total NULL values =
#
#  Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
print("Size of dataset is: ",data_set1.size)
# Out:
# Size of dataset is:  2403

# %%
print("Size of dataset is: ",data_set2.size)
# Out:
# Size of dataset is:  5376

# %%
data_set1.describe
# Out:
# <bound method NDFrame.describe of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
data_set2.describe
# Out:
# <bound method NDFrame.describe of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
data_set1.isnull().value_counts()
# Out:
# Region   Date   Frequency   Estimated Unemployment Rate (%)   Estimated Employed   Estimated Labour Participation Rate (%)  Region.1  longitude  latitude
# False   False  False       False                             False                False                                     False     False      False       267
# dtype: int64

# %%
data_set2.isnull().value_counts()
# Out:
# Region   Date   Frequency   Estimated Unemployment Rate (%)   Estimated Employed   Estimated Labour Participation Rate (%)  Area
# False   False  False       False                             False                False                                     False    740
# True    True   True        True                              True                 True                                      True      28
# dtype: int64

# %%
fig, ax = plt.subplots(figsize = (10, 6))
sns.heatmap(data_set1.corr(), annot=True, cmap="viridis").set(title='\n\nHeatmap of Correlated values for "Unemployment_Rate_upto_11_2020" \n\n')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10, 6))
sns.heatmap(data_set2.corr(), annot=True, cmap="autumn").set(title='\n\nHeatmap of Correlated values for "Unemployment_in_india" \n\n')
plt.show()

# %%
fig, ax = plt.subplots(figsize =(8, 7))
#labels
m=['Rural','Urban']
#title for chart
ax.set_title("\nPARTITION ACCORDING TO AREA IN \"Unemployment in india\" dataset",color="brown")
# Creating color parameters
colors = ( "blue" ,"magenta")
# Creating explode data
explode = (0.2, 0.0)
# Wedge properties
wp = { 'linewidth' : 1, 'edgecolor' : "green" }
# Creating plot
wedges, texts, autotexts = ax.pie(data_set2['Area'].value_counts(),
                                  autopct = "%0.2f",
                                  explode = explode,
                                  labels = m,
                                  shadow = True,
                                  colors = colors,
                                  startangle = 105,
                                  wedgeprops = wp,
                                  textprops = dict(color ="brown"))
# Adding legend
ax.legend(wedges,m,
          title ="AREA",
          loc ="center left",
          bbox_to_anchor =(1, 0, 0.5, 1))
 
plt.setp(autotexts, size = 8, weight ="bold")

plt.show()

# %%
data_set1['Region.1'].unique()
# Out:
# array(['South', 'Northeast', 'East', 'West', 'North'], dtype=object)

# %%
fig, ax = plt.subplots(figsize =(8, 7))
#labels
m=['South', 'Northeast', 'East', 'West', 'North']
#title for chart
ax.set_title("\nPARTITION ACCORDING TO REGION DIRECTIONS",color="brown")
# Creating color parameters
colors = ( "orange", "cyan", "brown","grey", "indigo")
# Creating explode data
explode = (0.1, 0.0, 0.2, 0.3, 0.0)
# Wedge properties
wp = { 'linewidth' : 1, 'edgecolor' : "green" }
# Creating plot
wedges, texts, autotexts = ax.pie(data_set1['Region.1'].value_counts(),
                                  autopct = "%0.2f",
                                  explode = explode,
                                  labels = m,
                                  shadow = True,
                                  colors = colors,
                                  startangle = 90,
                                  wedgeprops = wp,
                                  textprops = dict(color ="magenta"))
# Adding legend
ax.legend(wedges,m,
          title ="Directions",
          loc ="center left",
          bbox_to_anchor =(1.2, 0, 0.5, 1))
 
plt.setp(autotexts, size = 8, weight ="bold")

plt.show()

# %%
fig = plt.figure(figsize = (9, 6))
sns.lineplot(y=' Estimated Unemployment Rate (%)', data=data_set1, x=' Date',hue="Region.1")
plt.title('Unemployment according to Dates in different Regions')
plt.xticks(rotation=90)
plt.show()

# %%
fig = plt.figure(figsize = (9, 7))
sns.lineplot(y=' Estimated Labour Participation Rate (%)', data=data_set1, x=' Date',hue="Region.1")
plt.title('Unemployment according to Dates in different Regions')
plt.xticks(rotation=90)
plt.show()

# %%
fig = plt.figure(figsize = (9, 6))
sns.lineplot(y=' Estimated Employed', data=data_set1, x=' Date',hue="Region.1")
plt.title('Unemployment according to Dates in different Regions')
plt.xticks(rotation=90)
plt.show()

# %%
data_set1.hist(bins=200,figsize=[15,8])
plt.show()

# %%
data_set2.hist(bins=200,figsize=[10,8])
plt.show()

# %%
data_set1['Region'].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal'], dtype=object)

# %%
print("\nRelationship between 'Regions' & 'Estimated Labour Participation Rate' & 'Directions'\n")
plt.subplots(figsize=(21,5))
ax=sns.swarmplot(x='Region',y=' Estimated Labour Participation Rate (%)',data=data_set1,hue="Region.1")
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()
# Out:
# Relationship between 'Regions' & 'Estimated Labour Participation Rate' & 'Directions'

# %%
data_set2['Region'].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal', nan, 'Chandigarh'],
#       dtype=object)

# %%
print("\nRelationship between 'Regions' & 'Estimated Labour Participation Rate (%)' & 'Area'\n")
plt.subplots(figsize=(21,12))
ax=sns.swarmplot(x='Region',y=' Estimated Labour Participation Rate (%)',data=data_set2,hue="Area")
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
sns.set(style="whitegrid")
plt.show()
# Out:
# Relationship between 'Regions' & 'Estimated Labour Participation Rate (%)' & 'Area'

# %%
sns.pairplot(data_set1,height=2.7, aspect=1.5,diag_kws={'color':'red'},plot_kws={'color':'green'})
plt.show()

# %%
sns.pairplot(data_set2,height=4,diag_kws={'color':'red', 'bins':5})
plt.show()

# %%
plt.figure(figsize=(20, 5))
plt.plot(data_set2[' Estimated Employed'],color='green')
plt.xlabel('Estimated Employed')
plt.xlabel('Count')
plt.title('India Employed Statistics')
plt.show()

# %%
plt.figure(figsize=(20, 5))
plt.plot(data_set2[' Estimated Labour Participation Rate (%)'],color='orange')
plt.xlabel('Estimated Labour Participation Rate (%)')
plt.xlabel('Count')
plt.title('India Labour Participation Statistics')
plt.show()

# %%
plt.figure(figsize=(20, 5))
plt.plot(data_set2[' Estimated Unemployment Rate (%)'],color='magenta')
plt.xlabel('Estimated Unemployment Rate (%)')
plt.xlabel('Count')
plt.title('India Unemployment Statistics')
plt.show()

# %%
fig = plt.figure(figsize = (20, 8))
ax= sns.lineplot(y=' Estimated Unemployment Rate (%)', x='Region', data=data_set1)
ax1 = sns.lineplot(y=' Estimated Unemployment Rate (%)', x='Region', data=data_set2)
plt.xticks(rotation=40)
plt.show()
